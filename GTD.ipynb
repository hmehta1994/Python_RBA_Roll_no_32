# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()
sns.set(style="darkgrid")



import warnings
warnings.filterwarnings("ignore")



df=pd.read_csv(r'C:/Users/Harshil Mehta/Desktop/Python Project/Book1.csv',sep=";")
df.dropna() 
df.dropna(subset=["attacktype1_txt","gname","nperps","nkill"], inplace=True)

df["Visibility Scaled"]=df["iyear"]*100


sns.lineplot(x="iyear",y="nkill",data=df)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set()
sns.set(style="darkgrid")



import warnings
warnings.filterwarnings("ignore")



df=pd.read_csv(r'C:/Users/Harshil Mehta/Desktop/Python Project/Book1.csv',sep=";")
df.dropna() 
df.dropna(subset=["attacktype1_txt","gname","nperps","nkill","success","suicide"], inplace=True)

df["Visibility Scaled"]=df["iyear"]*100


sns.lineplot(x="iyear",y="nkill",data=df)

# %%
sns.distplot(df['iyear'])

# %%
sns.boxplot(df['nperps'],orient='vertical')

# %%
sns.violinplot(df['nperps'],orient='vertical',color='magenta')

# %%
sns.relplot(x="nperps",y="nkill",data=df,kind="scatter")

# %%
sns.relplot(x="nperps",y="nkill",hue="attacktype1_txt",data=df)

# %%
sns.relplot(x="nperps",y="nkill",hue="weaptype1_txt",data=df)

# %%
sns.relplot(x="nperps",y="nkill",hue="gname",data=df)

# %%
sns.relplot(x="nperps",y="nkill",hue="city",data=df)

# %%
sns.relplot(x="nperps",y="nkill",data=df,kind="scatter",size="Visibility Scaled",hue="attacktype1_txt")

# %%
sns.relplot(x="nperps",y="nkill",data=df,kind="scatter",size="Visibility Scaled",hue="weaptype1_txt")
